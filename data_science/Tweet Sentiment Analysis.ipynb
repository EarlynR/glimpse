# %%
import pandas as pd 
import numpy as np

# %%
tweets_data = pd.read_csv('doctor_tweets.csv')

# %%
tweets_data
# Out:
#        negative  -  \
# 0      negative  -
# 1      negative  -
# 2      negative  -
# 3      negative  -
# 4      negative  -
# 5      negative  -
# 6      negative  -
# 7      negative  -
# 8      negative  -
# 9      negative  -
# 10     negative  -
# 11     negative  -
# 12     negative  -
# 13     negative  -
# 14     negative  -
# 15     negative  -
# 16     negative  -
# 17     negative  -
# 18     negative  -
# 19     negative  -
# 20     negative  -
# 21     negative  -
# 22     negative  -
# 23     negative  -
# 24     negative  -
# 25     negative  -
# 26     negative  -
# 27     negative  -
# 28     negative  -
# 29     negative  -
# ...         ... ..
# 9974   negative  -
# 9975   negative  -
# 9976   negative  -
# 9977   negative  -
# 9978   negative  -
# 9979   negative  -
# 9980   negative  -
# 9981   negative  -
# 9982   negative  -
# 9983   negative  -
# 9984   negative  -
# 9985   negative  -
# 9986   negative  -
# 9987   negative  -
# 9988   negative  -
# ...
